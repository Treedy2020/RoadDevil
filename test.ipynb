# %%
import streamlit as st

help(st.text_area)
# Out:
# Help on method text_area in module streamlit.delta_generator:
#
# text_area(label: str, value: streamlit.type_util.SupportsStr = '', height: Optional[int] = None, max_chars: Optional[int] = None, key: Union[str, int, NoneType] = None, help: Optional[str] = None, on_change: Optional[Callable[..., NoneType]] = None, args: Optional[Tuple[Any, ...]] = None, kwargs: Optional[Dict[str, Any]] = None, *, placeholder: Optional[str] = None, disabled: bool = False, label_visibility: Literal['visible', 'hidden', 'collapsed'] = 'visible') -> str method of streamlit.delta_generator.DeltaGenerator instance
#     Display a multi-line text input widget.
#
#     Parameters
#     ----------
#     label : str
#         A short label explaining to the user what this input is for.
#         The label can optionally contain Markdown and supports the following
#         elements: Bold, Italics, Strikethroughs, Inline Code, Emojis, and Links.
#
#         This also supports:
#
# ...
